# %% [markdown]
# <a href="https://colab.research.google.com/github/JeferFernandoG/Prueba-1/blob/main/JuegoAhorcado3_fotosbasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Agregamos estas funciones que nos permiten tomar una foto directamente de la camara de nuestro dispositivo.( MIT License )

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %% [markdown]
# Con este codigo estamos leyendo una foto directamente de nuestra camara para poder realizar procesamiento de imagenes y crear nuestras aplicaciones más facil.

# %%
from IPython.display import Image
try:
  filename = take_photo('ramy2.jpg',0.8)
  print('Saved to {}'.format(filename))
   # Show the image which was just taken.
  display(Image(fillorrerr
except Exception as errerrerrerrerrerrerrerrerrerrerrerrerrerre lorrerrlorrerr:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
#   File "<ipython-input-7-2132e2f8a538>", line 6
#     display(Image(fillorrerr
#                  ^
# SyntaxError: '(' was never closed

# %%
import os

os.getcwd()
# Out:
# '/content'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3a393105-ce0b-46bb-809e-6a03209eb189" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a393105-ce0b-46bb-809e-6a03209eb189">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Veamos algunos comandos nuevos para procesamiento de imagenes usando OpenCV y otros, a continuación debes realizar modificaciones a los comandos para crear lineas, rectangulos, circulos y flechas hasta conseguir manipular su color , tamaño y posición en los resultados de las imagenes.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


font = cv2.FONT_HERSHEY_SIMPLEX

img2 = cv2.imread('Vinland Saga - 01.mkv_snapshot_06.02.307.jpg',1)

cv2.circle(img2, (1007,121), 60, (128, 0, 128), (-758))
cv2.line(img2, (1008,184), (1008,400), (128, 0, 128), (10))
cv2.line(img2, (1008,200), (876,300), (128, 0, 128), (10))
cv2.line(img2, (1008,200), (1126,300), (128, 0, 128), (10))
cv2.line(img2, (1008,400), (929,494), (128, 0, 128), (10))
cv2.line(img2, (1008,400), (1087,494), (128, 0, 128), (10))
cv2.line(img2, (1008,60), (1008,1), (0, 0, 0), (10))
cv2.line(img2, (1008,2), (1278,2), (0, 0, 0), (15))
cv2.line(img2, (1278,2), (1278,717), (0, 0, 0), (15))


cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F9403BE7DF0>

# %% [markdown]
# El Reto, se debe construir una aplicación que al colocar un objeto en la camara preferible de un color que este pintado todo del mismo color entonces la app le diga que color es. Se debe determinar cual es el color y señalarlo con un rectangulo, circulo ó flecha. Este codigo sirve tambien de insumo para comenzar la creación....Mucha suerte --- Les regalo este codigo para detectar color en pepas de cafe.

# %% [markdown]
# **A continuaciòn un codigo para detectar una letra en una palabra, con el objetivo de crear el juego del AHORCADO**

# %%
guiones=0

def revisar(palabra, letradivinar):
    quedaasi = ""  # variable final
    global guiones
    guiones=0
    for letra in palabra:  # para buscar letra por letra en la palabra
        if letra not in letradivinar: # si la letra en ese instante no esta en letraadivinar
            quedaasi += "_"  #  si no es la letraadivinar coloca un guiòn
            guiones=guiones+1

        else:
             quedaasi += letra


    return quedaasi

# %%
# !pip install gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from time import sleep
import cv2
import math
import random
from gtts import gTTS #Import Google Text to Speech
from IPython.display import Audio #Import Audio method from IPython's Display Class
from google.colab.patches import cv2_imshow
img2 = cv2.imread('Vinland Saga - 01.mkv_snapshot_06.02.307.jpg',1)
import time
import xlsxwriter



letrasadivinadas=""
malas=0
guiones=0
guionesant=0
band=0
reto=("einstein")

tts = gTTS("Bienvenido al juego del ahorcado, tienes 8 oportunidades para ganar el GAME",lang='es') #Provide the string to convert to speech
tts.save('1.wav') #save the string converted to speech as a .wav file
sound_file = '1.wav'
display(Audio(sound_file, autoplay=True))
while (1):
  print("---CUAL LETRA CREES QUE TIENE LA PALABRA  (SOLO DE UNA LETRA)----")
  letrasadivinadas=input() + letrasadivinadas
  guionesant=guiones
  largo=len(resultado)
  resultado=revisar(resultado, letrasadivinadas)


  if band == 1:
      if guiones < guionesant:
        time.sleep(2)
        print("--Correcto--")
        tts = gTTS("Tal vez puedas ganar,",lang='es') #Provide the string to convert to speech
        tts.save('1.wav') #save the string converted to speech as a .wav file
        sound_file = '1.wav'
        display(Audio(sound_file, autoplay=True))

        time.sleep(2)
      else:
        print("--incorrecto--")
        malas=malas+1
        tts = gTTS("perdiste una vida, jajajaja",lang='es') #Provide the string to convert to speech
        tts.save('1.wav') #save the string converted to speech as a .wav file
        sound_file = '1.wav'
        display(Audio(sound_file, autoplay=True))


  if band == 0:
     band=1
     guionesant=guiones
     if largo == guiones:
        print("--incorrecto--")
        malas=malas+1
        tts = gTTS("perdiste una vida",lang='es') #Provide the string to convert to speech
        tts.save('1.wav') #save the string converted to speech as a .wav file
        sound_file = '1.wav'
        display(Audio(sound_file, autoplay=True))
        time.sleep(3)

  if resultado==reto:
    print("GANASTE")
    break

  if malas == 1:
    time.sleep(2)

    cv2.line(img2, (1278,2), (1278,717), (0, 0, 0), (15))
    cv2.line(img2, (1008,60), (1008,1), (0, 0, 0), (10))
    cv2_imshow(img2)
    time.sleep(2)


  if malas == 2:
      #decir= "ey que pasa veneco?"
    cv2.circle(img2, (1007,121), 60, (128, 0, 128), (-758))
    cv2_imshow(img2)
    time.sleep(2)


  if malas == 3:
      #decir= "ey que pasa veneco?"
    cv2.line(img2, (1008,184), (1008,400), (128, 0, 128), (10))
    cv2_imshow(img2)
    time.sleep(2)

  if malas == 4:
        #decir= "ey que pasa veneco?"
    cv2.line(img2, (1008,200), (876,300), (128, 0, 128), (10))
    cv2_imshow(img2)
    time.sleep(2)

  if malas == 5:
        #decir= "ey que pasa veneco?"
    cv2.line(img2, (1008,200), (1126,300), (128, 0, 128), (10))
    cv2_imshow(img2)
    time.sleep(2)

  if malas == 6:
        #decir= "ey que pasa veneco?"
    cv2.line(img2, (1008,400), (929,494), (128, 0, 128), (10))
    cv2_imshow(img2)
    time.sleep(2)

  if malas == 7:
        #decir= "ey que pasa veneco?"
    cv2.line(img2, (1008,400), (1087,494), (128, 0, 128), (10))
    cv2_imshow(img2)
    time.sleep(2)
    print('¡PERDISTE!')
    break

  print("-----AVANCE DE LAS LETRAS DESCUBIERTAS--------")
  print("        ")
  print(resultado)
  print("        ")

  tts = gTTS("La palabra correcta es, Einstein", lang='es') #Provide the string to convert to speech
  tts.save('1.wav') #save the string converted to speech as a .wav file
  sound_file = '1.wav'
  Audio(sound_file,autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---CUAL LETRA CREES QUE TIENE LA PALABRA  (SOLO DE UNA LETRA)----

# %% [markdown]
# **Esto es un codigo Regalo para detectar pepas de cafe en estado maduro, verde ò dañado.**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2438ed73-4622-46c2-9c5a-bc3f6fc14055" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2438ed73-4622-46c2-9c5a-bc3f6fc14055">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cafe3.JPG to cafe3.JPG

# %%
import os

os.getcwd()
# Out:
# '/content'

# %%
import cv2
import math
from google.colab.patches import cv2_imshow
import numpy as np


imagen = cv2.imread('/content/cafe3.JPG')
imagenNormal = cv2.imread('/content/cafe3.JPG')
imagen = cv2.resize(imagen,(800,800), interpolation = cv2.INTER_CUBIC)
imagenNormal = cv2.resize(imagenNormal,(500,500), interpolation = cv2.INTER_CUBIC)

font = cv2.FONT_HERSHEY_SIMPLEX
rojos= 0
verdes=0
total=0
tverdes=0
trojos=0
tnegros=0
negros=0


for y in range(800):
    for x in range(800):
        b,g,r=imagen[x,y]  # bgr
        promedio=(int(b)+int(g) + int(r))/3
        if int(g) > int(b) and int(g) > int(r) and abs(int(g)-promedio)>7 :
            verdes=verdes + 1
            imagen[x,y]=[0, 255, 0]
        elif int(r) > int(b) and int(r) > int(g) and abs(int(r)-promedio)>17:
            rojos=rojos+1
            imagen[x,y]=[0, 0, 255]
        elif abs(int(r)-promedio)<10 and promedio<120 :
            negros=negros+1
            imagen[x,y]=[0, 0, 0]

total= verdes + rojos + negros
tverdes= int(verdes*100/total)
trojos= int(rojos*100/total)
tnegros = int(negros*100/total)

Strfinal= "Verdes= " + str(tverdes) + "%"
Strfinal2= "Maduro= " + str(trojos)  + "%"
Strfinal3= "Sobremaduro= " + str(tnegros) + "%"

cv2.putText(imagen,Strfinal,(100,50),font,1,(0,255,0),2,cv2.LINE_AA)
cv2.putText(imagen,Strfinal2,(100,100),font,1,(0,0,255),2,cv2.LINE_AA)
cv2.putText(imagen,Strfinal3,(100,150),font,1,(0,0,0),2,cv2.LINE_AA)


imagen2=imagen
imagen = cv2.resize(imagen,(500,500), interpolation = cv2.INTER_CUBIC)
cv2_imshow(imagenNormal)
cv2_imshow(imagen)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F34C582CA58>
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F34C582CA20>
